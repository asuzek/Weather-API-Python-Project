# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key 

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_data=[]
# Error city counter
i=0
for city in cities:

    # Build query URL based on current element in units
    query_url = url + "appid=" + api_key + "&q=" + city + "&units=imperial"

    # Get weather data
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    
    try:
        weather_data.append({
            "City":city,
            "Cloudiness": weather_json["clouds"]["all"], 
            "Country":weather_json["sys"]["country"], 
            "Date":weather_json["dt"], 
            "Humidity":weather_json["main"]["humidity"], 
            "Lat":weather_json["coord"]["lat"], 
            "Lng":weather_json["coord"]["lon"], 
            "Max Temp":weather_json["main"]["temp_max"], 
            "Wind Speed":weather_json["wind"]["speed"]})
        #print(city + " :Ok.")
    except Exception as e:
        if i==0:
            print("Cities with Errors:")
        i+=1
        print("{}- {}: Error with type: {} and value: {}".format(i, city, type(e), e))
print("------------------------------------- \n Data Retrieval Complete \n -------------------------------------")
# Out:
# Cities with Errors:
# 1- louisbourg: Error with type: <class 'KeyError'> and value: 'clouds'
# 2- illoqqortoormiut: Error with type: <class 'KeyError'> and value: 'clouds'
# 3- samusu: Error with type: <class 'KeyError'> and value: 'clouds'
# 4- marcona: Error with type: <class 'KeyError'> and value: 'clouds'
# 5- warqla: Error with type: <class 'KeyError'> and value: 'clouds'
# 6- taolanaro: Error with type: <class 'KeyError'> and value: 'clouds'
# 7- malwan: Error with type: <class 'KeyError'> and value: 'clouds'
# 8- belushya guba: Error with type: <class 'KeyError'> and value: 'clouds'
# 9- port-de-paix: Error with type: <class 'KeyError'> and value: 'clouds'
# 10- canitas: Error with type: <class 'KeyError'> and value: 'clouds'
# 11- mrirt: Error with type: <class 'KeyError'> and value: 'clouds'
# 12- doctor pedro p. pena: Error with type: <class 'KeyError'> and value: 'clouds'
# 13- amderma: Error with type: <class 'KeyError'> and value: 'clouds'
# 14- nizhneyansk: Error with type: <class 'KeyError'> and value: 'clouds'
# 15- malakal: Error with type: <class 'KeyError'> and value: 'clouds'
# 16- vaitupu: Error with type: <class 'KeyError'> and value: 'clouds'
# 17- fevralsk: Error with type: <class 'KeyError'> and value: 'clouds'
# 18- dien bien: Error with type: <class 'KeyError'> and value: 'clouds'
# 19- khonuu: Error with type: <class 'KeyError'> and value: 'clouds'
# 20- mocambique: Error with type: <class 'KeyError'> and value: 'clouds'
# 21- balimo: Error with type: <class 'KeyError'> and value: 'clouds'
# 22- kadykchan: Error with type: <class 'KeyError'> and value: 'clouds'
# 23- rawah: Error with type: <class 'KeyError'> and value: 'clouds'
# 24- bengkulu: Error with type: <class 'KeyError'> and value: 'clouds'
# 25- burica: Error with type: <class 'KeyError'> and value: 'clouds'
# 26- andenes: Error with type: <class 'KeyError'> and value: 'clouds'
# 27- mahadday weyne: Error with type: <class 'KeyError'> and value: 'clouds'
# 28- attawapiskat: Error with type: <class 'KeyError'> and value: 'clouds'
# 29- kuche: Error with type: <class 'KeyError'> and value: 'clouds'
# 30- grand river south east: Error with type: <class 'KeyError'> and value: 'clouds'
# 31- umm durman: Error with type: <class 'KeyError'> and value: 'clouds'
# 32- safaga: Error with type: <class 'KeyError'> and value: 'clouds'
# 33- ambodifototra: Error with type: <class 'KeyError'> and value: 'clouds'
# 34- tumannyy: Error with type: <class 'KeyError'> and value: 'clouds'
# 35- rolim de moura: Error with type: <class 'KeyError'> and value: 'clouds'
# 36- barentsburg: Error with type: <class 'KeyError'> and value: 'clouds'
# 37- sakakah: Error with type: <class 'KeyError'> and value: 'clouds'
# 38- kushmurun: Error with type: <class 'KeyError'> and value: 'clouds'
# 39- angra: Error with type: <class 'KeyError'> and value: 'clouds'
# 40- sentyabrskiy: Error with type: <class 'KeyError'> and value: 'clouds'
# 41- azimur: Error with type: <class 'KeyError'> and value: 'clouds'
# 42- bankja: Error with type: <class 'KeyError'> and value: 'clouds'
# 43- tawkar: Error with type: <class 'KeyError'> and value: 'clouds'
# 44- asau: Error with type: <class 'KeyError'> and value: 'clouds'
# 45- paradwip: Error with type: <class 'KeyError'> and value: 'clouds'
# 46- lolua: Error with type: <class 'KeyError'> and value: 'clouds'
# 47- marang: Error with type: <class 'KeyError'> and value: 'clouds'
# 48- barbar: Error with type: <class 'KeyError'> and value: 'clouds'
# 49- karaul: Error with type: <class 'KeyError'> and value: 'clouds'
# 50- tuggurt: Error with type: <class 'KeyError'> and value: 'clouds'
# 51- tsihombe: Error with type: <class 'KeyError'> and value: 'clouds'
# 52- ipora: Error with type: <class 'KeyError'> and value: 'clouds'
# 53- mys shmidta: Error with type: <class 'KeyError'> and value: 'clouds'
# 54- sodertalje: Error with type: <class 'KeyError'> and value: 'clouds'
# 55- mirina: Error with type: <class 'KeyError'> and value: 'clouds'
# 56- domoni: Error with type: <class 'KeyError'> and value: 'clouds'
# 57- xiongshi: Error with type: <class 'KeyError'> and value: 'clouds'
# 58- mentok: Error with type: <class 'KeyError'> and value: 'clouds'
# 59- labutta: Error with type: <class 'KeyError'> and value: 'clouds'
# 60- sorvag: Error with type: <class 'KeyError'> and value: 'clouds'
# 61- bolungarvik: Error with type: <class 'KeyError'> and value: 'clouds'
# 62- qurayyat: Error with type: <class 'KeyError'> and value: 'clouds'
# 63- maghama: Error with type: <class 'KeyError'> and value: 'clouds'
# 64- ozgon: Error with type: <class 'KeyError'> and value: 'clouds'
# 65- tapaua: Error with type: <class 'KeyError'> and value: 'clouds'
# 66- grand centre: Error with type: <class 'KeyError'> and value: 'clouds'
# 67- gurgan: Error with type: <class 'KeyError'> and value: 'clouds'
# 68- maloshuyka: Error with type: <class 'KeyError'> and value: 'clouds'
# 69- ardahan: Error with type: <class 'KeyError'> and value: 'clouds'
# 70- longlac: Error with type: <class 'KeyError'> and value: 'clouds'
# -------------------------------------
#  Data Retrieval Complete
#  -------------------------------------

# %%
df=pd.DataFrame.from_dict(weather_data)
df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      ishigaki          75      JP  1551916800        68  24.34  124.16
# 1       tautira          40      PF  1551918786        58 -17.73 -149.15
# 2          lamu           0      ID  1551919158        86   0.57  122.30
# 3       ipixuna          90      BR  1551916800        94  -1.76  -48.80
# 4  puerto ayora          20      EC  1551916800        78  -0.74  -90.35
#
#    Max Temp  Wind Speed
# 0     66.20       18.34
# 1     87.80        5.82
# 2     77.57        2.95
# 3     77.00        3.36
# 4     80.60        6.93

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Obtain the x and y coordinates for each of the three city types
latitude=df["Lat"]
max_tem=df["Max Temp"]

# Build the scatter plots for each city types
plt.scatter(latitude, max_tem, marker="o", facecolor="lightcoral", 
            edgecolors="black", alpha=0.5)

#Limit the chart
plt.ylim(-40, 100)
plt.xlim(-60, 85)

# Incorporate the other graph properties
plt.grid(color='r', linestyle='-', linewidth=0.5)

# Create a legend
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature F")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Obtain the x and y coordinates for each of the three city types
latitude=df["Lat"]
hum=df["Humidity"]


# Build the scatter plots for each city types
plt.scatter(latitude, hum, marker="o", facecolor="lightcoral", edgecolors="black", alpha=0.5)

#Limit the chart
plt.ylim(-5, 105)
plt.xlim(-60, 85)

# Incorporate the other graph properties
plt.grid(color='r', linestyle='-', linewidth=0.5)

# Create a legend
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Obtain the x and y coordinates for each of the three city types
latitude=df["Lat"]
cloud=df["Cloudiness"]

# Build the scatter plots for each city types
plt.scatter(latitude, cloud, marker="o", facecolor="lightcoral", edgecolors="black", alpha=0.5)

#Limit the chart
plt.ylim(-5, 105)
plt.xlim(-60, 85)

# Incorporate the other graph properties
plt.grid(color='r', linestyle='-', linewidth=0.5)

# Create a legend
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Obtain the x and y coordinates for each of the three city types
latitude=df["Lat"]
wind=df["Wind Speed"]

# Build the scatter plots for each city types
plt.scatter(latitude, wind, marker="o", facecolor="lightcoral", edgecolors="black", alpha=0.5)

#Limit the chart
plt.ylim(-5, 50)
plt.xlim(-60, 85)

# Incorporate the other graph properties
plt.grid(color='r', linestyle='-', linewidth=0.5)

# Create a legend
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.show()
